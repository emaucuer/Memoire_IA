# %%
conda install requests
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\emaucuer\Anaconda3
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.13.0               |   py39haa95532_0         923 KB
#     ------------------------------------------------------------
#                                            Total:         923 KB
#
# The following packages will be UPDATED:
#
#   conda                               4.12.0-py39haa95532_0 --> 4.13.0-py39haa95532_0
#
#
#
# ...
#
# conda-4.13.0         | 923 KB    |            |   0%
# conda-4.13.0         | 923 KB    | 1          |   2%
# conda-4.13.0         | 923 KB    | ########## | 100%
# conda-4.13.0         | 923 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# ...

# %%
import requests
import json
import pandas as pd

# %%
token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..SKjgTASIBsaz_o9kFuij-iX95NPaS4MsG55S1tzsV4g"


start = "19910101"
end="19910102"
lat=45
lon=3

era5_url = "https://weather-climate.heka.ai/api/c13s/history/reanalysis/era5-land"
params_era5 = {"var" : "t_2m", "start" :start, "end" : end, "lat" : lat, "lon" : lon, "fmt" : "json"}

print('collecting u')    
response = requests.get(era5_url, headers = {"Authorization" : f"Bearer {token}"}, params = params_era5)
era5 = pd.read_json(response.text)

era5
# Out:
# collecting u
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 14>()
#      12 print('collecting u')
#      13 response = requests.get(era5_url, headers = {"Authorization" : f"Bearer {token}"}, params = params_era5)
# ---> 14 era5 = pd.read_json(response.text)
#      16 era5
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
headers = {'accept': 'application/json','Authorization': f'Bearer {token}'}

params = {'xvar': 'false', 'format': 'json'}


url10="https://weather-climate.heka.ai/api/c13s/details/variables?model=Era5-Land&format=json"
response10 = requests.get(url10, params=params, headers=headers)
print(response10.status_code)
response10.json()


var = pd.read_json(response10.text)
var
# Out:
# 200
#                                           description  \
# 0   Eastward component of the 10m wind. It is the ...
# 1   Northward component of the 10m wind. It is the...
# 2   Temperature to which the air, at 2 metres abov...
# 3             Temperature of the air 2m above surface
# 4   Total precipitation rate. Total precipitation ...
# 5   This parameter is the flux of solar radiation ...
# 6   Potential evaporation (pev) in the current ECM...
# 7   This variable is the total amount of run off f...
# 8   It represents the fraction (0-1) of the cell /...
# 9                       Air pressure at surface level
# 10  Total precipitation accumulated from the begin...
# 11  This parameter is the amount of solar radiatio...
#
#                     indrabot_name indrabot_units  \
# 0                           u_10m            m/s
# 1                           v_10m            m/s
# 2                    tdewpoint_2m              K
# 3                            t_2m              K
# ...

# %%
headers = {'accept': 'application/json','Authorization': f'Bearer {token}'}

params = {'xvar': 'false', 'format': 'json'}


url10="https://weather-climate.heka.ai/api/c13s/details/variables?model=CORDEX&format=json"
response10 = requests.get(url10, params=params, headers=headers)
print(response10.status_code)
response10.json()


var = pd.read_json(response10.text)
var
# Out:
# 200
#                                          description indrabot_name  \
# 0            Temperature of the air 2m above surface          t_2m
# 1  Speed of the horizontal air movement (sum of n...         w_10m
# 2  Highest value of the hourly 10m wind speed tha...      wmax_day
#
#   indrabot_units origin_name origin_units
# 0              K         tas            K
# 1            m/s     sfcWind          m/s
# 2            m/s  sfcWindmax          m/s
